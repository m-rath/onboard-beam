# %%
import os, re, requests, json
from google.cloud import secretmanager
import pandas as pd
pd.options.display.width = 140

# %% [markdown]
# For each neighbourhood in AB_NYC_2019.csv, get coordinates of a listing

# %%
bnb_df = pd.read_csv("../MP_csv_files/AB_NYC_2019.csv")
bnb_df = bnb_df[['id','neighbourhood_group','neighbourhood','latitude','longitude']]

# %%
# Navy Yard coordinates of first_listing fail to fit any NTA region;
# Little Neck and Woodlawn coordinates of last_listing fail to fit any NTA region;
# Thus, first and last are gathered here, and one will be dropped after NTA lookup.

bnb_sample = []
for nhood in bnb_df.neighbourhood.unique():
    
    first_listing = bnb_df.loc[bnb_df.neighbourhood == nhood][:1]
    last_listing = bnb_df.loc[bnb_df.neighbourhood == nhood][-1:]

    for listing in [first_listing, last_listing]:
        exemplar = {
            'bnb_ref_id': listing.values[0][0],
            'bnb_boro': listing.values[0][1],
            'bnb_nhood': listing.values[0][2],
            'latitude': listing.values[0][3],
            'longitude': listing.values[0][4]
        }

        bnb_sample.append(exemplar)

# %%
len(bnb_sample)
# Out:
# 442

# %% [markdown]
# ___

# %% [markdown]
# Align each neighbourhood with NTA2020 code, using representative listing's coordinates

# %%
def access_secret_version(project_id, secret_id, version_id):
    client = secretmanager.SecretManagerServiceClient()
    name = f"projects/{project_id}/secrets/{secret_id}/versions/{version_id}"
    response = client.access_secret_version(request={"name": name})
    return response.payload.data.decode("UTF-8")

# %%
PROJECT_ID = os.getenv("PROJECT_ID")
NYC_APP_TOKEN = access_secret_version(PROJECT_ID, "NYC_APP_TOKEN", "latest")
MAP_URL = access_secret_version(PROJECT_ID, "MAP_URL", "latest")

# %%
def lookup_nta(latitude, longitude):
    nta = {}

    url = f"{MAP_URL}?$where=intersects(the_geom, 'POINT({longitude} {latitude})')"
    headers = {"X-App-Token": NYC_APP_TOKEN}
    response = requests.get(url, headers=headers)
    jsn = json.loads(response.text)

    fields = [
        'boroname',
        'countyfips',
        'nta2020',
        'ntaname',
        'cdta2020',
        'cdtaname']
        
    if jsn:
        for field in fields:
            nta[field] = jsn[0][field]
    return nta

# %%
# Could do this for every listing individually, 
# but ~50,000 API calls might get throttled.
# For now, this will do.

nta_lookup = []
for nhood in bnb_sample:
    nta = lookup_nta(nhood['latitude'], nhood['longitude'])
    nhood.update(nta)
    nta_lookup.append(nhood)
nta_df = pd.DataFrame(nta_lookup)

# %% [markdown]
# ___

# %% [markdown]
# Quick check on bnb listings' fit to NTA map

# %%
nta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bnb_ref_id  442 non-null    int64
#  1   bnb_boro    442 non-null    object
#  2   bnb_nhood   442 non-null    object
#  3   latitude    442 non-null    float64
#  4   longitude   442 non-null    float64
#  5   boroname    439 non-null    object
#  6   countyfips  439 non-null    object
#  7   nta2020     439 non-null    object
#  8   ntaname     439 non-null    object
#  9   cdta2020    439 non-null    object
#  10  cdtaname    439 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 38.1+ KB

# %%
nta_df.loc[nta_df.boroname.isna()==True]
# Out:
#      bnb_ref_id  bnb_boro    bnb_nhood  latitude  longitude boroname countyfips nta2020 ntaname cdta2020 cdtaname
# 131    33853642     Bronx     Woodlawn  40.90406  -73.86286      NaN        NaN     NaN     NaN      NaN      NaN
# 292     3079125  Brooklyn    Navy Yard  40.70481  -73.97755      NaN        NaN     NaN     NaN      NaN      NaN
# 421    35515780    Queens  Little Neck  40.77444  -73.73373      NaN        NaN     NaN     NaN      NaN      NaN

# %%
nta_df = nta_df.dropna()

# %%
nta_df.drop_duplicates(subset='bnb_nhood', keep='first').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 0 to 440
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bnb_ref_id  221 non-null    int64
#  1   bnb_boro    221 non-null    object
#  2   bnb_nhood   221 non-null    object
#  3   latitude    221 non-null    float64
#  4   longitude   221 non-null    float64
#  5   boroname    221 non-null    object
#  6   countyfips  221 non-null    object
#  7   nta2020     221 non-null    object
#  8   ntaname     221 non-null    object
#  9   cdta2020    221 non-null    object
#  10  cdtaname    221 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 20.7+ KB

# %%
nta_df = nta_df.drop_duplicates(subset='bnb_nhood', keep='first')

# %%
# nta_df.to_csv("bnb_nhood_sample_coords_nta.csv")

# %% [markdown]
# ___
# Link bnb neighbourhoods with demographics of interest

# %%
df_profiles = pd.read_csv("demographics_by_nta_2019.csv", index_col=0)

# %%
df_profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 0 to 261
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GeoID      262 non-null    object
#  1   MdGRE      211 non-null    object
#  2   MdVlE      209 non-null    object
#  3   EA_BchDHP  216 non-null    float64
#  4   Pop_1E     262 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 12.3+ KB

# %%
side_input = pd.merge(nta_df, df_profiles, how="left", left_on="nta2020", right_on="GeoID")

# %%
side_input
# Out:
#      bnb_ref_id       bnb_boro     bnb_nhood  latitude  longitude       boroname countyfips nta2020  \
# 0          2539       Brooklyn    Kensington  40.64749  -73.97237       Brooklyn        047  BK1203
# 1          2595      Manhattan       Midtown  40.75362  -73.98377      Manhattan        061  MN0502
# 2          3647      Manhattan        Harlem  40.80902  -73.94190      Manhattan        061  MN1002
# 3      21741106       Brooklyn  Clinton Hill  40.69479  -73.96812       Brooklyn        047  BK0204
# 4          5022      Manhattan   East Harlem  40.79851  -73.94399      Manhattan        061  MN1102
# ..          ...            ...           ...       ...        ...            ...        ...     ...
# 216    22856025  Staten Island   Bull's Head  40.60295  -74.17117  Staten Island        085  SI0204
# 217    23597323  Staten Island      New Dorp  40.57044  -74.11747  Staten Island        085  SI0202
# 218    26258351  Staten Island     Rossville  40.54790  -74.21017  Staten Island        085  SI0303
# 219    26703677         Queens  Breezy Point  40.56605  -73.86994         Queens        081  QN8492
# 220    27088022  Staten Island   Willowbrook  40.59886  -74.13217  Staten Island        085  SI0203
#
#                                                ntaname cdta2020                                           cdtaname   GeoID  MdGRE  \
# 0                                           Kensington     BK12  BK12 Borough Park-Kensington (CD 12 Approximat...  BK1203  1,607
# 1                                 Midtown-Times Square     MN05  MN05 Midtown-Flatiron-Union Square (CD 5 Appro...  MN0502  2,931
# 2                                       Harlem (North)     MN10                     MN10 Harlem (CD 10 Equivalent)  MN1002  1,089
# 3                                         Clinton Hill     BK02  BK02 Downtown Brooklyn-Fort Greene (CD 2 Appro...  BK0204  1,971
# 4                                  East Harlem (North)     MN11                MN11 East Harlem (CD 11 Equivalent)  MN1102    873
# ..                                                 ...      ...                                                ...     ...    ...
# 216      New Springville-Willowbrook-Bulls Head-Travis     SI02               SI02 Mid-Island (CD 2 Approximation)  SI0204  1,551
# 217                             New Dorp-Midland Beach     SI02               SI02 Mid-Island (CD 2 Approximation)  SI0202  1,536
# 218                            Arden Heights-Rossville     SI03              SI03 South Shore (CD 3 Approximation)  SI0303  1,242
# 219       Jacob Riis Park-Fort Tilden-Breezy Point Tip     QN84     QN84 Jamaica Bay (East) (JIA 84 Approximation)  QN8492    NaN
# 220  Todt Hill-Emerson Hill-Lighthouse Hill-Manor H...     SI02               SI02 Mid-Island (CD 2 Approximation)  SI0203  1,226
#
#          MdVlE  EA_BchDHP  Pop_1E
# 0      693,439       46.7  38,788
# 1    1,098,496       78.2  19,860
# 2      609,513       35.1  82,712
# 3      730,698       65.8  27,082
# 4      612,027       27.5  64,762
# ..         ...        ...     ...
# 216    498,178       34.0  43,057
# 217    484,631       29.7  27,538
# 218    444,250       32.8  30,900
# 219    749,999       27.3      11
# 220    647,364       41.5  31,111
#
# [221 rows x 16 columns]

# %%
side_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 0 to 220
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bnb_ref_id  221 non-null    int64
#  1   bnb_boro    221 non-null    object
#  2   bnb_nhood   221 non-null    object
#  3   latitude    221 non-null    float64
#  4   longitude   221 non-null    float64
#  5   boroname    221 non-null    object
#  6   countyfips  221 non-null    object
#  7   nta2020     221 non-null    object
#  8   ntaname     221 non-null    object
#  9   cdta2020    221 non-null    object
#  10  cdtaname    221 non-null    object
#  11  GeoID       221 non-null    object
#  12  MdGRE       218 non-null    object
#  13  MdVlE       218 non-null    object
#  14  EA_BchDHP   219 non-null    float64
#  15  Pop_1E      221 non-null    object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 29.4+ KB

# %%
side_input[side_input.MdGRE.isna()]
# Out:
#      bnb_ref_id bnb_boro     bnb_nhood  latitude  longitude boroname countyfips nta2020                                       ntaname  \
# 37        32363   Queens      Flushing  40.74028  -73.83168   Queens        081  QN0871         Mount Hebron & Cedar Grove Cemeteries
# 161     5288228    Bronx       Tremont  40.83875  -73.88728    Bronx        005  BX0391                                  Crotona Park
# 219    26703677   Queens  Breezy Point  40.56605  -73.86994   Queens        081  QN8492  Jacob Riis Park-Fort Tilden-Breezy Point Tip
#
#     cdta2020                                           cdtaname   GeoID MdGRE    MdVlE  EA_BchDHP Pop_1E
# 37      QN08  QN08 Fresh Meadows-Hillcrest-Briarwood (CD 8 A...  QN0871   NaN      NaN        NaN      0
# 161     BX03  BX03 Morrisania-Crotona Park East (CD 3 Approx...  BX0391   NaN      NaN        NaN      0
# 219     QN84     QN84 Jamaica Bay (East) (JIA 84 Approximation)  QN8492   NaN  749,999       27.3     11

# %%
side_input[side_input.MdVlE.isna()]
# Out:
#      bnb_ref_id   bnb_boro        bnb_nhood  latitude  longitude   boroname countyfips nta2020                                ntaname  \
# 37        32363     Queens         Flushing  40.74028  -73.83168     Queens        081  QN0871  Mount Hebron & Cedar Grove Cemeteries
# 132     1839818  Manhattan  Stuyvesant Town  40.73196  -73.97932  Manhattan        061  MN0601   Stuyvesant Town-Peter Cooper Village
# 161     5288228      Bronx          Tremont  40.83875  -73.88728      Bronx        005  BX0391                           Crotona Park
#
#     cdta2020                                           cdtaname   GeoID  MdGRE MdVlE  EA_BchDHP  Pop_1E
# 37      QN08  QN08 Fresh Meadows-Hillcrest-Briarwood (CD 8 A...  QN0871    NaN   NaN        NaN       0
# 132     MN06  MN06 East Midtown-Murray Hill (CD 6 Approximat...  MN0601  2,524   NaN       81.5  22,335
# 161     BX03  BX03 Morrisania-Crotona Park East (CD 3 Approx...  BX0391    NaN   NaN        NaN       0

# %%
side_input[side_input.EA_BchDHP.isna()]
# Out:
#      bnb_ref_id bnb_boro bnb_nhood  latitude  longitude boroname countyfips nta2020                                ntaname cdta2020  \
# 37        32363   Queens  Flushing  40.74028  -73.83168   Queens        081  QN0871  Mount Hebron & Cedar Grove Cemeteries     QN08
# 161     5288228    Bronx   Tremont  40.83875  -73.88728    Bronx        005  BX0391                           Crotona Park     BX03
#
#                                               cdtaname   GeoID MdGRE MdVlE  EA_BchDHP Pop_1E
# 37   QN08 Fresh Meadows-Hillcrest-Briarwood (CD 8 A...  QN0871   NaN   NaN        NaN      0
# 161  BX03 Morrisania-Crotona Park East (CD 3 Approx...  BX0391   NaN   NaN        NaN      0

# %% [markdown]
# Check on Breezy Point, Tremont, Stuyvesant, Flushing.

# %% [markdown]
# ___
# Breezy Point?

# %%
bnb_df.loc[bnb_df.neighbourhood == "Breezy Point"]
# Out:
#              id neighbourhood_group neighbourhood  latitude  longitude
# 33698  26703677              Queens  Breezy Point  40.56605  -73.86994
# 34429  27301638              Queens  Breezy Point  40.56568  -73.87009
# 48751  36417725              Queens  Breezy Point  40.56546  -73.86968

# %%
lookup_nta(40.56568, -73.87009)
# Out:
# {'boroname': 'Queens',
#  'countyfips': '081',
#  'nta2020': 'QN8492',
#  'ntaname': 'Jacob Riis Park-Fort Tilden-Breezy Point Tip',
#  'cdta2020': 'QN84',
#  'cdtaname': 'QN84 Jamaica Bay (East) (JIA 84 Approximation)'}

# %%
lookup_nta(40.56546,-73.86968)
# Out:
# {'boroname': 'Queens',
#  'countyfips': '081',
#  'nta2020': 'QN8492',
#  'ntaname': 'Jacob Riis Park-Fort Tilden-Breezy Point Tip',
#  'cdta2020': 'QN84',
#  'cdtaname': 'QN84 Jamaica Bay (East) (JIA 84 Approximation)'}

# %%
lookup_nta(40.56605,-73.86994)
# Out:
# {'boroname': 'Queens',
#  'countyfips': '081',
#  'nta2020': 'QN8492',
#  'ntaname': 'Jacob Riis Park-Fort Tilden-Breezy Point Tip',
#  'cdta2020': 'QN84',
#  'cdtaname': 'QN84 Jamaica Bay (East) (JIA 84 Approximation)'}

# %% [markdown]
# All three bnb Breezy Point listings are located within a single NTA,<br>
# for which rent is NaN and population is eleven, according to my NTA sources;<br>
# PUMA demographics might exist, but then granularity of demographics would be mixed,<br>
# some NTA and some PUMA.<br>
# I prefer finer granularity, at expense of Breezy Point stats.<br><br>
#
# According to map, QN1403 borders the missing data to the east and west,<br>
# and NTA demographics exist for QN1403. Breezy Point solved.

# %%
df_profiles[df_profiles.GeoID=='QN8492']
# Out:
#       GeoID MdGRE    MdVlE  EA_BchDHP Pop_1E
# 255  QN8492   NaN  749,999       27.3     11

# %%
df_profiles[df_profiles.GeoID=='QN1403']
# Out:
#       GeoID  MdGRE    MdVlE  EA_BchDHP  Pop_1E
# 180  QN1403  1,418  615,257       45.0  24,768

# %%
(27.3/100)*11
# Out:
# 3.003

# %%
24768+11
# Out:
# 24779

# %%
(24768*(45/100) + 3) / 24779
# Out:
# 0.4499213043302797

# %%
side_input.loc[side_input.bnb_nhood == "Breezy Point", "GeoID"] = 'QN1403'
side_input.loc[side_input.bnb_nhood == "Breezy Point", "MdGRE"] = '1,418'
side_input.loc[side_input.bnb_nhood == "Breezy Point", "MdVlE"] = '615,257'
side_input.loc[side_input.bnb_nhood == "Breezy Point", "EA_BchDHP"] = 45.0
side_input.loc[side_input.bnb_nhood == "Breezy Point", "Pop_1E"] = '24,768'

# %% [markdown]
# ___
# Tremont? <br>
# At least one listing is too close to a park, with 0 people and NaN for other stats.

# %%
bnb_df.loc[bnb_df.neighbourhood == "Tremont"]
# Out:
#              id neighbourhood_group neighbourhood  latitude  longitude
# 7226    5288228               Bronx       Tremont  40.83875  -73.88728
# 7402    5495927               Bronx       Tremont  40.83887  -73.88805
# 7636    5749147               Bronx       Tremont  40.84061  -73.88858
# 16538  13248565               Bronx       Tremont  40.84268  -73.89294
# 16677  13335424               Bronx       Tremont  40.84559  -73.89815
# 22216  17899730               Bronx       Tremont  40.84546  -73.89013
# 22708  18375815               Bronx       Tremont  40.84647  -73.89299
# 23082  18690466               Bronx       Tremont  40.84594  -73.89358
# 39256  30592546               Bronx       Tremont  40.84289  -73.88773
# 41503  32263166               Bronx       Tremont  40.84740  -73.89612
# 43053  33422954               Bronx       Tremont  40.84581  -73.88890

# %%
tm = bnb_df.loc[bnb_df.neighbourhood == "Tremont"]

# %%
tm_lookups = []
for lat, lon in zip(tm.latitude, tm.longitude):
    nta = lookup_nta(lat, lon)
    tm_lookups.append(nta)

# %%
tm_nta = [tm['nta2020'] for tm in tm_lookups]

# %%
tm_nta
# Out:
# ['BX0391',
#  'BX0391',
#  'BX0602',
#  'BX0602',
#  'BX0602',
#  'BX0602',
#  'BX0602',
#  'BX0602',
#  'BX0602',
#  'BX0602',
#  'BX0602']

# %%
set(tm_nta) # {'BX0391', 'BX0602'}
# Out:
# {'BX0391', 'BX0602'}

# %% [markdown]
# Good, Tremont has another possible NTA for stats lookup

# %%
df_profiles.loc[df_profiles.GeoID == 'BX0391']
# Out:
#       GeoID MdGRE MdVlE  EA_BchDHP Pop_1E
# 233  BX0391   NaN   NaN        NaN      0

# %%
df_profiles.loc[df_profiles.GeoID == 'BX0602']
# Out:
#      GeoID  MdGRE    MdVlE  EA_BchDHP  Pop_1E
# 67  BX0602  1,048  391,332       13.7  31,270

# %%
side_input.loc[side_input.bnb_nhood == "Tremont", "GeoID"] = 'BX0602'
side_input.loc[side_input.bnb_nhood == "Tremont", "MdGRE"] = '1,048'
side_input.loc[side_input.bnb_nhood == "Tremont", "MdVlE"] = '391,332'
side_input.loc[side_input.bnb_nhood == "Tremont", "EA_BchDHP"] = 13.7
side_input.loc[side_input.bnb_nhood == "Tremont", "Pop_1E"] = '31,270'

# %%
side_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 0 to 220
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bnb_ref_id  221 non-null    int64
#  1   bnb_boro    221 non-null    object
#  2   bnb_nhood   221 non-null    object
#  3   latitude    221 non-null    float64
#  4   longitude   221 non-null    float64
#  5   boroname    221 non-null    object
#  6   countyfips  221 non-null    object
#  7   nta2020     221 non-null    object
#  8   ntaname     221 non-null    object
#  9   cdta2020    221 non-null    object
#  10  cdtaname    221 non-null    object
#  11  GeoID       221 non-null    object
#  12  MdGRE       220 non-null    object
#  13  MdVlE       219 non-null    object
#  14  EA_BchDHP   220 non-null    float64
#  15  Pop_1E      221 non-null    object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 29.4+ KB

# %% [markdown]
# ___
# Stuyvesant?  NaN for median value of owner-occupied homes.

# %%
side_input.loc[side_input.bnb_nhood == "Stuyvesant Town"]
# Out:
#      bnb_ref_id   bnb_boro        bnb_nhood  latitude  longitude   boroname countyfips nta2020                               ntaname  \
# 132     1839818  Manhattan  Stuyvesant Town  40.73196  -73.97932  Manhattan        061  MN0601  Stuyvesant Town-Peter Cooper Village
#
#     cdta2020                                           cdtaname   GeoID  MdGRE MdVlE  EA_BchDHP  Pop_1E
# 132     MN06  MN06 East Midtown-Murray Hill (CD 6 Approximat...  MN0601  2,524   NaN       81.5  22,335

# %%
bnb_df[bnb_df.neighbourhood == "Stuyvesant Town"]
# Out:
#              id neighbourhood_group    neighbourhood  latitude  longitude
# 3101    1839818           Manhattan  Stuyvesant Town  40.73196  -73.97932
# 3731    2250170           Manhattan  Stuyvesant Town  40.73205  -73.98094
# 6744    4837935           Manhattan  Stuyvesant Town  40.72912  -73.97624
# 6784    4854552           Manhattan  Stuyvesant Town  40.73001  -73.97579
# 9007    6914268           Manhattan  Stuyvesant Town  40.73390  -73.97743
# 9478    7269771           Manhattan  Stuyvesant Town  40.73050  -73.98043
# 12309   9511685           Manhattan  Stuyvesant Town  40.73288  -73.97984
# 18297  14353077           Manhattan  Stuyvesant Town  40.72940  -73.97751
# 18381  14443766           Manhattan  Stuyvesant Town  40.73304  -73.97421
# 19722  15789384           Manhattan  Stuyvesant Town  40.73167  -73.98146
# 20236  16189705           Manhattan  Stuyvesant Town  40.73052  -73.97780
# 20612  16376497           Manhattan  Stuyvesant Town  40.73125  -73.97891
# 21310  16963544           Manhattan  Stuyvesant Town  40.73126  -73.98149
# 22252  17941948           Manhattan  Stuyvesant Town  40.73117  -73.97616
# 28058  21913859           Manhattan  Stuyvesant Town  40.72734  -73.97203
# 30807  23855867           Manhattan  Stuyvesant Town  40.73101  -73.97347
# 31677  24696044           Manhattan  Stuyvesant Town  40.73082  -73.98023
# 33472  26458835           Manhattan  Stuyvesant Town  40.73391  -73.97857
# 34554  27398613           Manhattan  Stuyvesant Town  40.73182  -73.98158
# 35174  27904745           Manhattan  Stuyvesant Town  40.72957  -73.97715
# 35716  28345080           Manhattan  Stuyvesant Town  40.73389  -73.98016
# 36776  29230470           Manhattan  Stuyvesant Town  40.73092  -73.98146
# 36827  29264544           Manhattan  Stuyvesant Town  40.73341  -73.98000
# 39603  30819919           Manhattan  Stuyvesant Town  40.73284  -73.97635
# 41882  32554746           Manhattan  Stuyvesant Town  40.73180  -73.97999
# 42311  32840036           Manhattan  Stuyvesant Town  40.73379  -73.97754
# 42634  33096377           Manhattan  Stuyvesant Town  40.73223  -73.98134
# 43197  33511856           Manhattan  Stuyvesant Town  40.73351  -73.97798
# 43974  33972589           Manhattan  Stuyvesant Town  40.73193  -73.97971
# 44183  34088961           Manhattan  Stuyvesant Town  40.73110  -73.97750
# 45920  35001663           Manhattan  Stuyvesant Town  40.73159  -73.97472
# 46136  35097684           Manhattan  Stuyvesant Town  40.73232  -73.97784
# 48024  36038287           Manhattan  Stuyvesant Town  40.73221  -73.97941
# 48116  36095625           Manhattan  Stuyvesant Town  40.73143  -73.97549
# 48201  36137531           Manhattan  Stuyvesant Town  40.73549  -73.97707
# 48448  36270538           Manhattan  Stuyvesant Town  40.73258  -73.98039
# 48676  36380964           Manhattan  Stuyvesant Town  40.73380  -73.97972

# %%
sv = bnb_df[bnb_df.neighbourhood == "Stuyvesant Town"]

sv_lookups = []
for lat, lon in zip(sv.latitude, sv.longitude):
    nta = lookup_nta(lat, lon)
    sv_lookups.append(nta)

# %%
sv_nta = [sv['nta2020'] for sv in sv_lookups]

# %%
set(sv_nta)
# Out:
# {'MN0601'}

# %% [markdown]
# Nothing we can do about that, apparently. Unless the map helps... <br>
# No, this area has no homes. Planned development with apartments, only.<br>
# So Stuyvesant gets NaN for median home value.

# %% [markdown]
# ___
# Flushing?<br>
# At least one listing is too close to a cemetary, with 0 people and NaN for other stats.

# %%
bnb_df.loc[bnb_df.neighbourhood == "Flushing"]
# Out:
#              id neighbourhood_group neighbourhood  latitude  longitude
# 143       32363              Queens      Flushing  40.74028  -73.83168
# 1271     546383              Queens      Flushing  40.75578  -73.81948
# 1649     748656              Queens      Flushing  40.76372  -73.79201
# 1710     774791              Queens      Flushing  40.75612  -73.82517
# 1832     818337              Queens      Flushing  40.75979  -73.81016
# ...         ...                 ...           ...       ...        ...
# 48419  36243764              Queens      Flushing  40.74407  -73.82645
# 48600  36335028              Queens      Flushing  40.74761  -73.81380
# 48652  36356906              Queens      Flushing  40.75825  -73.83369
# 48790  36427429              Queens      Flushing  40.75104  -73.81459
# 48858  36458668              Queens      Flushing  40.74387  -73.82556
#
# [426 rows x 5 columns]

# %%
fl = bnb_df[bnb_df.neighbourhood == "Flushing"]

# %%
fl_lookups = []
for lat, lon in zip(fl.latitude, fl.longitude):
    nta = lookup_nta(lat, lon)
    fl_lookups.append(nta)

# %%
fl_nta = [fl['nta2020'] for fl in fl_lookups]

# %%
set(fl_nta)

# {'QN0704',
#  'QN0705',
#  'QN0706',
#  'QN0707',
#  'QN0791',
#  'QN0801',
#  'QN0802',
#  'QN0803',
#  'QN0871',
#  'QN1101',
#  'QN8191'}
# Out:
# {'QN0704',
#  'QN0705',
#  'QN0706',
#  'QN0707',
#  'QN0791',
#  'QN0801',
#  'QN0802',
#  'QN0803',
#  'QN0871',
#  'QN1101',
#  'QN8191'}

# %% [markdown]
# Wow, 11 different NTAs for bnb listings in Flushing.<br>
# Tukey's ninthers method will do, for rent and home value -- median of medians, as informal approx of median.

# %%
dfw = pd.DataFrame()

for nta_code in set(fl_nta):
    
    dfw = pd.concat([dfw, df_profiles[df_profiles.GeoID == nta_code]], axis=0)

# %%
dfw
# Out:
#       GeoID  MdGRE    MdVlE  EA_BchDHP  Pop_1E
# 146  QN0706  1,496  762,699       25.8  20,164
# 148  QN0801  1,558  350,880       44.9  34,292
# 149  QN0802  1,215  661,998       33.4  35,756
# 144  QN0704  1,566  725,104       23.6  54,051
# 147  QN0707  1,453  352,632       20.4  59,788
# 150  QN0803  1,808  782,087       46.8  22,938
# 161  QN1101  1,772  752,432       35.7  33,671
# 145  QN0705  1,439  815,136       22.6  30,137

# %%
for col in ['MdGRE', 'MdVlE', 'Pop_1E']:
    dfw[col] = dfw[col].apply(lambda x: int(x.replace(',','')))

# %%
dfw_educ = sum(dfw.EA_BchDHP*dfw.Pop_1E)/sum(dfw.Pop_1E)

# %%
dfw_educ 
# EA_BchDHP = 29.9
# Out:
# 29.938825022266393

# %%
sum(dfw.Pop_1E) 
# Pop_1E = '290,797'
# Out:
# 290797

# %%
dfw.describe().loc['50%'] 
# MdGRE = '1,527'
# MdVlE = '738,768'
# Out:
# MdGRE          1527.0
# MdVlE        738768.0
# EA_BchDHP        29.6
# Pop_1E        33981.5
# Name: 50%, dtype: float64

# %%
side_input.loc[side_input.bnb_nhood == "Flushing", "GeoID"] = 'QN0706' # GeoID not used moving forward, actually
side_input.loc[side_input.bnb_nhood == "Flushing", "MdGRE"] = '1,527'
side_input.loc[side_input.bnb_nhood == "Flushing", "MdVlE"] = '738,768'
side_input.loc[side_input.bnb_nhood == "Flushing", "EA_BchDHP"] = 29.9
side_input.loc[side_input.bnb_nhood == "Flushing", "Pop_1E"] = '290,797'

# %% [markdown]
# ___

# %%
side_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 0 to 220
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bnb_ref_id  221 non-null    int64
#  1   bnb_boro    221 non-null    object
#  2   bnb_nhood   221 non-null    object
#  3   latitude    221 non-null    float64
#  4   longitude   221 non-null    float64
#  5   boroname    221 non-null    object
#  6   countyfips  221 non-null    object
#  7   nta2020     221 non-null    object
#  8   ntaname     221 non-null    object
#  9   cdta2020    221 non-null    object
#  10  cdtaname    221 non-null    object
#  11  GeoID       221 non-null    object
#  12  MdGRE       221 non-null    object
#  13  MdVlE       220 non-null    object
#  14  EA_BchDHP   221 non-null    float64
#  15  Pop_1E      221 non-null    object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 29.4+ KB

# %% [markdown]
# Only missing value is for median home value in Stuyvesant.

# %%
# side_input.to_csv("bnb_nta_side_input.csv")

# %% [markdown]
# ___

# %% [markdown]
# Now let's format the side_input to suit our needs.

# %%
dicts = []
for row in range(len(side_input.index)):
    nh = {
        'nta_code': side_input['nta2020'][row],
        'median_rent': side_input['MdGRE'][row],
        'median_home_value': side_input['MdVlE'][row],
        'percent_atleast_bachdeg': side_input['EA_BchDHP'][row],
        'population': side_input['Pop_1E'][row],
        'nta_name': side_input['ntaname'][row]
    }
    elem = {side_input['bnb_nhood'][row]: {k:v for k,v in nh.items()}}
    dicts.append(elem)

# %%
dicts
# Out:
# [{'Kensington': {'nta_code': 'BK1203',
#    'median_rent': '1,607',
#    'median_home_value': '693,439',
#    'percent_atleast_bachdeg': 46.7,
#    'population': '38,788',
#    'nta_name': 'Kensington'}},
#  {'Midtown': {'nta_code': 'MN0502',
#    'median_rent': '2,931',
#    'median_home_value': '1,098,496',
#    'percent_atleast_bachdeg': 78.2,
#    'population': '19,860',
#    'nta_name': 'Midtown-Times Square'}},
#  {'Harlem': {'nta_code': 'MN1002',
#    'median_rent': '1,089',
#    'median_home_value': '609,513',
#    'percent_atleast_bachdeg': 35.1,
#    'population': '82,712',
#    'nta_name': 'Harlem (North)'}},
#  {'Clinton Hill': {'nta_code': 'BK0204',
#    'median_rent': '1,971',
#    'median_home_value': '730,698',
#    'percent_atleast_bachdeg': 65.8,
#    'population': '27,082',
#    'nta_name': 'Clinton Hill'}},
#  {'East Harlem': {'nta_code': 'MN1102',
#    'median_rent': '873',
#    'median_home_value': '612,027',
#    'percent_atleast_bachdeg': 27.5,
#    'population': '64,762',
#    'nta_name': 'East Harlem (North)'}},
#  {'Murray Hill': {'nta_code': 'MN0603',
#    'median_rent': '2,576',
#    'median_home_value': '734,233',
#    'percent_atleast_bachdeg': 78.5,
#    'population': '56,943',
#    'nta_name': 'Murray Hill-Kips Bay'}},
#  {'Bedford-Stuyvesant': {'nta_code': 'BK0301',
#    'median_rent': '1,467',
#    'median_home_value': '1,068,813',
#    'percent_atleast_bachdeg': 41.5,
#    'population': '82,014',
#    'nta_name': 'Bedford-Stuyvesant (West)'}},
#  {"Hell's Kitchen": {'nta_code': 'MN0402',
#    'median_rent': '1,935',
#    'median_home_value': '863,574',
#    'percent_atleast_bachdeg': 70.7,
#    'population': '52,941',
#    'nta_name': "Hell's Kitchen"}},
#  {'Upper West Side': {'nta_code': 'MN0703',
#    'median_rent': '1,469',
#    'median_home_value': '1,054,785',
#    'percent_atleast_bachdeg': 61.3,
#    'population': '52,334',
#    'nta_name': 'Upper West Side-Manhattan Valley'}},
#  {'Chinatown': {'nta_code': 'MN0301',
#    'median_rent': '960',
#    'median_home_value': '711,236',
#    'percent_atleast_bachdeg': 23.3,
#    'population': '40,082',
#    'nta_name': 'Chinatown-Two Bridges'}},
#  {'South Slope': {'nta_code': 'BK0602',
#    'median_rent': '2,443',
#    'median_home_value': '1,360,901',
#    'percent_atleast_bachdeg': 81.6,
#    'population': '58,877',
#    'nta_name': 'Park Slope'}},
#  {'West Village': {'nta_code': 'MN0203',
#    'median_rent': '2,388',
#    'median_home_value': '1,127,813',
#    'percent_atleast_bachdeg': 83.8,
#    'population': '33,204',
#    'nta_name': 'West Village'}},
#  {'Williamsburg': {'nta_code': 'BK0102',
#    'median_rent': '2,384',
#    'median_home_value': '1,164,622',
#    'percent_atleast_bachdeg': 60.5,
#    'population': '57,774',
#    'nta_name': 'Williamsburg'}},
#  {'Fort Greene': {'nta_code': 'BK0203',
#    'median_rent': '1,526',
#    'median_home_value': '967,623',
#    'percent_atleast_bachdeg': 53.8,
#    'population': '32,653',
#    'nta_name': 'Fort Greene'}},
#  {'Chelsea': {'nta_code': 'MN0401',
#    'median_rent': '2,331',
#    'median_home_value': '742,892',
#    'percent_atleast_bachdeg': 74.4,
#    'population': '60,836',
#    'nta_name': 'Chelsea-Hudson Yards'}},
#  {'Crown Heights': {'nta_code': 'BK0802',
#    'median_rent': '1,305',
#    'median_home_value': '877,324',
#    'percent_atleast_bachdeg': 38.4,
#    'population': '82,184',
#    'nta_name': 'Crown Heights (North)'}},
#  {'Park Slope': {'nta_code': 'BK0602',
#    'median_rent': '2,443',
#    'median_home_value': '1,360,901',
#    'percent_atleast_bachdeg': 81.6,
#    'population': '58,877',
#    'nta_name': 'Park Slope'}},
#  {'Windsor Terrace': {'nta_code': 'BK0701',
#    'median_rent': '2,071',
#    'median_home_value': '1,036,264',
#    'percent_atleast_bachdeg': 69.9,
#    'population': '24,496',
#    'nta_name': 'Windsor Terrace-South Slope'}},
#  {'Inwood': {'nta_code': 'MN1203',
#    'median_rent': '1,340',
#    'median_home_value': '358,495',
#    'percent_atleast_bachdeg': 34.8,
#    'population': '41,936',
#    'nta_name': 'Inwood'}},
#  {'East Village': {'nta_code': 'MN0303',
#    'median_rent': '1,420',
#    'median_home_value': '717,721',
#    'percent_atleast_bachdeg': 57.2,
#    'population': '68,026',
#    'nta_name': 'East Village'}},
#  {'Greenpoint': {'nta_code': 'BK0104',
#    'median_rent': '1,411',
#    'median_home_value': '972,668',
#    'percent_atleast_bachdeg': 42.3,
#    'population': '52,363',
#    'nta_name': 'East Williamsburg'}},
#  {'Bushwick': {'nta_code': 'BK0401',
#    'median_rent': '1,628',
#    'median_home_value': '680,439',
#    'percent_atleast_bachdeg': 35.7,
#    'population': '53,557',
#    'nta_name': 'Bushwick (West)'}},
#  {'Flatbush': {'nta_code': 'BK1402',
#    'median_rent': '1,455',
#    'median_home_value': '839,079',
#    'percent_atleast_bachdeg': 43.6,
#    'population': '39,988',
#    'nta_name': 'Flatbush (West)-Ditmas Park-Parkville'}},
#  {'Lower East Side': {'nta_code': 'MN0301',
#    'median_rent': '960',
#    'median_home_value': '711,236',
#    'percent_atleast_bachdeg': 23.3,
#    'population': '40,082',
#    'nta_name': 'Chinatown-Two Bridges'}},
#  {'Prospect-Lefferts Gardens': {'nta_code': 'BK0902',
#    'median_rent': '1,393',
#    'median_home_value': '667,751',
#    'percent_atleast_bachdeg': 37.2,
#    'population': '46,940',
#    'nta_name': 'Prospect Lefferts Gardens-Wingate'}},
#  {'Long Island City': {'nta_code': 'QN0201',
#    'median_rent': '3,006',
#    'median_home_value': '1,009,933',
#    'percent_atleast_bachdeg': 78.2,
#    'population': '20,199',
#    'nta_name': 'Long Island City-Hunters Point'}},
#  {'Kips Bay': {'nta_code': 'MN0603',
#    'median_rent': '2,576',
#    'median_home_value': '734,233',
#    'percent_atleast_bachdeg': 78.5,
#    'population': '56,943',
#    'nta_name': 'Murray Hill-Kips Bay'}},
#  {'SoHo': {'nta_code': 'MN0201',
#    'median_rent': '1,844',
#    'median_home_value': '2,000,000',
#    'percent_atleast_bachdeg': 69.1,
#    'population': '22,489',
#    'nta_name': 'SoHo-Little Italy-Hudson Square'}},
#  {'Upper East Side': {'nta_code': 'MN0801',
#    'median_rent': '2,352',
#    'median_home_value': '985,567',
#    'percent_atleast_bachdeg': 76.3,
#    'population': '82,085',
#    'nta_name': 'Upper East Side-Lenox Hill-Roosevelt Island'}},
#  {'Prospect Heights': {'nta_code': 'BK0801',
#    'median_rent': '1,988',
#    'median_home_value': '1,058,393',
#    'percent_atleast_bachdeg': 71.3,
#    'population': '22,301',
#    'nta_name': 'Prospect Heights'}},
#  {'Washington Heights': {'nta_code': 'MN1201',
#    'median_rent': '1,288',
#    'median_home_value': '468,495',
#    'percent_atleast_bachdeg': 29.0,
#    'population': '83,914',
#    'nta_name': 'Washington Heights (South)'}},
#  {'Woodside': {'nta_code': 'QN0203',
#    'median_rent': '1,543',
#    'median_home_value': '561,461',
#    'percent_atleast_bachdeg': 30.1,
#    'population': '46,191',
#    'nta_name': 'Woodside'}},
#  {'Brooklyn Heights': {'nta_code': 'BK0201',
#    'median_rent': '2,384',
#    'median_home_value': '938,572',
#    'percent_atleast_bachdeg': 81.8,
#    'population': '23,758',
#    'nta_name': 'Brooklyn Heights'}},
#  {'Carroll Gardens': {'nta_code': 'BK0601',
#    'median_rent': '1,810',
#    'median_home_value': '1,424,561',
#    'percent_atleast_bachdeg': 62.7,
#    'population': '60,893',
#    'nta_name': 'Carroll Gardens-Cobble Hill-Gowanus-Red Hook'}},
#  {'Gowanus': {'nta_code': 'BK0601',
#    'median_rent': '1,810',
#    'median_home_value': '1,424,561',
#    'percent_atleast_bachdeg': 62.7,
#    'population': '60,893',
#    'nta_name': 'Carroll Gardens-Cobble Hill-Gowanus-Red Hook'}},
#  {'Flatlands': {'nta_code': 'BK1801',
#    'median_rent': '1,422',
#    'median_home_value': '521,539',
#    'percent_atleast_bachdeg': 32.5,
#    'population': '70,560',
#    'nta_name': 'Flatlands'}},
#  {'Cobble Hill': {'nta_code': 'BK0202',
#    'median_rent': '2,558',
#    'median_home_value': '1,115,073',
#    'percent_atleast_bachdeg': 70.7,
#    'population': '35,288',
#    'nta_name': 'Downtown Brooklyn-DUMBO-Boerum Hill'}},
#  {'Flushing': {'nta_code': 'QN0871',
#    'median_rent': '1,527',
#    'median_home_value': '738,768',
#    'percent_atleast_bachdeg': 29.9,
#    'population': '290,797',
#    'nta_name': 'Mount Hebron & Cedar Grove Cemeteries'}},
#  {'Boerum Hill': {'nta_code': 'BK0202',
#    'median_rent': '2,558',
#    'median_home_value': '1,115,073',
#    'percent_atleast_bachdeg': 70.7,
#    'population': '35,288',
#    'nta_name': 'Downtown Brooklyn-DUMBO-Boerum Hill'}},
#  {'Sunnyside': {'nta_code': 'QN0202',
#    'median_rent': '1,613',
#    'median_home_value': '489,329',
#    'percent_atleast_bachdeg': 39.8,
#    'population': '49,399',
#    'nta_name': 'Sunnyside'}},
#  {'DUMBO': {'nta_code': 'BK0202',
#    'median_rent': '2,558',
#    'median_home_value': '1,115,073',
#    'percent_atleast_bachdeg': 70.7,
#    'population': '35,288',
#    'nta_name': 'Downtown Brooklyn-DUMBO-Boerum Hill'}},
#  {'St. George': {'nta_code': 'SI0101',
#    'median_rent': '1,166',
#    'median_home_value': '397,727',
#    'percent_atleast_bachdeg': 34.6,
#    'population': '17,221',
#    'nta_name': 'St. George-New Brighton'}},
#  {'Highbridge': {'nta_code': 'BX0402',
#    'median_rent': '1,116',
#    'median_home_value': '359,999',
#    'percent_atleast_bachdeg': 14.5,
#    'population': '32,234',
#    'nta_name': 'Highbridge'}},
#  {'Financial District': {'nta_code': 'MN0101',
#    'median_rent': '3,279',
#    'median_home_value': '1,034,750',
#    'percent_atleast_bachdeg': 84.8,
#    'population': '46,466',
#    'nta_name': 'Financial District-Battery Park City'}},
#  {'Ridgewood': {'nta_code': 'QN0502',
#    'median_rent': '1,576',
#    'median_home_value': '636,024',
#    'percent_atleast_bachdeg': 29.9,
#    'population': '72,983',
#    'nta_name': 'Ridgewood'}},
#  {'Morningside Heights': {'nta_code': 'MN0901',
#    'median_rent': '1,672',
#    'median_home_value': '736,241',
#    'percent_atleast_bachdeg': 70.2,
#    'population': '37,379',
#    'nta_name': 'Morningside Heights'}},
#  {'Jamaica': {'nta_code': 'QN1204',
#    'median_rent': '1,097',
#    'median_home_value': '442,159',
#    'percent_atleast_bachdeg': 21.9,
#    'population': '30,813',
#    'nta_name': 'Springfield Gardens (North)-Rochdale Village'}},
#  {'Middle Village': {'nta_code': 'QN0504',
#    'median_rent': '1,589',
#    'median_home_value': '685,238',
#    'percent_atleast_bachdeg': 35.0,
#    'population': '34,891',
#    'nta_name': 'Middle Village'}},
#  {'NoHo': {'nta_code': 'MN0202',
#    'median_rent': '2,506',
#    'median_home_value': '1,352,543',
#    'percent_atleast_bachdeg': 85.5,
#    'population': '32,189',
#    'nta_name': 'Greenwich Village'}},
#  {'Ditmars Steinway': {'nta_code': 'QN0101',
#    'median_rent': '1,802',
#    'median_home_value': '838,503',
#    'percent_atleast_bachdeg': 48.8,
#    'population': '47,234',
#    'nta_name': 'Astoria (North)-Ditmars-Steinway'}},
#  {'Flatiron District': {'nta_code': 'MN0602',
#    'median_rent': '2,626',
#    'median_home_value': '866,579',
#    'percent_atleast_bachdeg': 84.1,
#    'population': '26,497',
#    'nta_name': 'Gramercy'}},
#  {'Roosevelt Island': {'nta_code': 'MN0801',
#    'median_rent': '2,352',
#    'median_home_value': '985,567',
#    'percent_atleast_bachdeg': 76.3,
#    'population': '82,085',
#    'nta_name': 'Upper East Side-Lenox Hill-Roosevelt Island'}},
#  {'Greenwich Village': {'nta_code': 'MN0202',
#    'median_rent': '2,506',
#    'median_home_value': '1,352,543',
#    'percent_atleast_bachdeg': 85.5,
#    'population': '32,189',
#    'nta_name': 'Greenwich Village'}},
#  {'Little Italy': {'nta_code': 'MN0201',
#    'median_rent': '1,844',
#    'median_home_value': '2,000,000',
#    'percent_atleast_bachdeg': 69.1,
#    'population': '22,489',
#    'nta_name': 'SoHo-Little Italy-Hudson Square'}},
#  {'East Flatbush': {'nta_code': 'BK1701',
#    'median_rent': '1,389',
#    'median_home_value': '513,768',
#    'percent_atleast_bachdeg': 26.5,
#    'population': '44,162',
#    'nta_name': 'East Flatbush-Erasmus'}},
#  {'Tompkinsville': {'nta_code': 'SI0104',
#    'median_rent': '1,374',
#    'median_home_value': '521,018',
#    'percent_atleast_bachdeg': 39.8,
#    'population': '34,958',
#    'nta_name': 'West New Brighton-Silver Lake-Grymes Hill'}},
#  {'Astoria': {'nta_code': 'QN0104',
#    'median_rent': '1,608',
#    'median_home_value': '680,881',
#    'percent_atleast_bachdeg': 43.9,
#    'population': '35,517',
#    'nta_name': 'Astoria (East)-Woodside (North)'}},
#  {'Clason Point': {'nta_code': 'BX0902',
#    'median_rent': '902',
#    'median_home_value': '409,102',
#    'percent_atleast_bachdeg': 17.7,
#    'population': '35,921',
#    'nta_name': 'Soundview-Clason Point'}},
#  {'Eastchester': {'nta_code': 'BX1202',
#    'median_rent': '1,314',
#    'median_home_value': '447,038',
#    'percent_atleast_bachdeg': 24.7,
#    'population': '55,008',
#    'nta_name': 'Eastchester-Edenwald-Baychester'}},
#  {'Kingsbridge': {'nta_code': 'BX0801',
#    'median_rent': '1,342',
#    'median_home_value': '140,377',
#    'percent_atleast_bachdeg': 24.5,
#    'population': '35,851',
#    'nta_name': 'Kingsbridge Heights-Van Cortlandt Village'}},
#  {'Two Bridges': {'nta_code': 'MN0301',
#    'median_rent': '960',
#    'median_home_value': '711,236',
#    'percent_atleast_bachdeg': 23.3,
#    'population': '40,082',
#    'nta_name': 'Chinatown-Two Bridges'}},
#  {'Queens Village': {'nta_code': 'QN0804',
#    'median_rent': '1,586',
#    'median_home_value': '676,587',
#    'percent_atleast_bachdeg': 47.9,
#    'population': '23,806',
#    'nta_name': 'Jamaica Estates-Holliswood'}},
#  {'Rockaway Beach': {'nta_code': 'QN1402',
#    'median_rent': '1,002',
#    'median_home_value': '395,556',
#    'percent_atleast_bachdeg': 22.7,
#    'population': '41,562',
#    'nta_name': 'Rockaway Beach-Arverne-Edgemere'}},
#  {'Forest Hills': {'nta_code': 'QN0602',
#    'median_rent': '1,750',
#    'median_home_value': '418,887',
#    'percent_atleast_bachdeg': 60.4,
#    'population': '87,668',
#    'nta_name': 'Forest Hills'}},
#  {'Nolita': {'nta_code': 'MN0201',
#    'median_rent': '1,844',
#    'median_home_value': '2,000,000',
#    'percent_atleast_bachdeg': 69.1,
#    'population': '22,489',
#    'nta_name': 'SoHo-Little Italy-Hudson Square'}},
#  {'Woodlawn': {'nta_code': 'BX1203',
#    'median_rent': '1,384',
#    'median_home_value': '432,702',
#    'percent_atleast_bachdeg': 26.8,
#    'population': '48,046',
#    'nta_name': 'Wakefield-Woodlawn'}},
#  {'University Heights': {'nta_code': 'BX0501',
#    'median_rent': '1,134',
#    'median_home_value': '383,045',
#    'percent_atleast_bachdeg': 13.2,
#    'population': '55,215',
#    'nta_name': 'University Heights (South)-Morris Heights'}},
#  {'Gravesend': {'nta_code': 'BK1501',
#    'median_rent': '1,465',
#    'median_home_value': '771,334',
#    'percent_atleast_bachdeg': 37.4,
#    'population': '51,364',
#    'nta_name': 'Gravesend (East)-Homecrest'}},
#  {'Gramercy': {'nta_code': 'MN0602',
#    'median_rent': '2,626',
#    'median_home_value': '866,579',
#    'percent_atleast_bachdeg': 84.1,
#    'population': '26,497',
#    'nta_name': 'Gramercy'}},
#  {'Allerton': {'nta_code': 'BX1103',
#    'median_rent': '1,446',
#    'median_home_value': '484,665',
#    'percent_atleast_bachdeg': 29.2,
#    'population': '29,209',
#    'nta_name': 'Pelham Gardens'}},
#  {'East New York': {'nta_code': 'BK0505',
#    'median_rent': '1,176',
#    'median_home_value': '512,980',
#    'percent_atleast_bachdeg': 13.3,
#    'population': '44,646',
#    'nta_name': 'East New York-City Line'}},
#  {'Theater District': {'nta_code': 'MN0502',
#    'median_rent': '2,931',
#    'median_home_value': '1,098,496',
#    'percent_atleast_bachdeg': 78.2,
#    'population': '19,860',
#    'nta_name': 'Midtown-Times Square'}},
#  {'Concourse Village': {'nta_code': 'BX0401',
#    'median_rent': '1,191',
#    'median_home_value': '209,702',
#    'percent_atleast_bachdeg': 16.3,
#    'population': '65,708',
#    'nta_name': 'Concourse-Concourse Village'}},
#  {'Sheepshead Bay': {'nta_code': 'BK1503',
#    'median_rent': '1,296',
#    'median_home_value': '544,973',
#    'percent_atleast_bachdeg': 41.4,
#    'population': '65,167',
#    'nta_name': 'Sheepshead Bay-Manhattan Beach-Gerritsen Beach'}},
#  {'Emerson Hill': {'nta_code': 'SI0203',
#    'median_rent': '1,226',
#    'median_home_value': '647,364',
#    'percent_atleast_bachdeg': 41.5,
#    'population': '31,111',
#    'nta_name': 'Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights'}},
#  {'Fort Hamilton': {'nta_code': 'BK1001',
#    'median_rent': '1,566',
#    'median_home_value': '803,818',
#    'percent_atleast_bachdeg': 49.3,
#    'population': '80,127',
#    'nta_name': 'Bay Ridge'}},
#  {'Bensonhurst': {'nta_code': 'BK1101',
#    'median_rent': '1,407',
#    'median_home_value': '859,133',
#    'percent_atleast_bachdeg': 29.5,
#    'population': '97,786',
#    'nta_name': 'Bensonhurst'}},
#  {'Tribeca': {'nta_code': 'MN0102',
#    'median_rent': '2,650',
#    'median_home_value': '2,000,000',
#    'percent_atleast_bachdeg': 82.4,
#    'population': '22,883',
#    'nta_name': 'Tribeca-Civic Center'}},
#  {'Shore Acres': {'nta_code': 'SI0103',
#    'median_rent': '1,116',
#    'median_home_value': '431,029',
#    'percent_atleast_bachdeg': 29.3,
#    'population': '22,783',
#    'nta_name': 'Rosebank-Shore Acres-Park Hill'}},
#  {'Sunset Park': {'nta_code': 'BK0702',
#    'median_rent': '1,591',
#    'median_home_value': '863,295',
#    'percent_atleast_bachdeg': 31.0,
#    'population': '51,456',
#    'nta_name': 'Sunset Park (West)'}},
#  {'Concourse': {'nta_code': 'BX0401',
#    'median_rent': '1,191',
#    'median_home_value': '209,702',
#    'percent_atleast_bachdeg': 16.3,
#    'population': '65,708',
#    'nta_name': 'Concourse-Concourse Village'}},
#  {'Elmhurst': {'nta_code': 'QN0401',
#    'median_rent': '1,548',
#    'median_home_value': '585,963',
#    'percent_atleast_bachdeg': 26.7,
#    'population': '96,436',
#    'nta_name': 'Elmhurst'}},
#  {'Brighton Beach': {'nta_code': 'BK1303',
#    'median_rent': '1,268',
#    'median_home_value': '612,167',
#    'percent_atleast_bachdeg': 49.1,
#    'population': '30,583',
#    'nta_name': 'Brighton Beach'}},
#  {'Jackson Heights': {'nta_code': 'QN0301',
#    'median_rent': '1,530',
#    'median_home_value': '419,594',
#    'percent_atleast_bachdeg': 27.3,
#    'population': '91,836',
#    'nta_name': 'Jackson Heights'}},
#  {'Cypress Hills': {'nta_code': 'BK0501',
#    'median_rent': '1,432',
#    'median_home_value': '536,066',
#    'percent_atleast_bachdeg': 13.7,
#    'population': '40,908',
#    'nta_name': 'Cypress Hills'}},
#  {'St. Albans': {'nta_code': 'QN1205',
#    'median_rent': '1,478',
#    'median_home_value': '447,812',
#    'percent_atleast_bachdeg': 24.6,
#    'population': '51,429',
#    'nta_name': 'St. Albans'}},
#  {'Arrochar': {'nta_code': 'SI0201',
#    'median_rent': '1,151',
#    'median_home_value': '490,276',
#    'percent_atleast_bachdeg': 32.6,
#    'population': '35,918',
#    'nta_name': 'Grasmere-Arrochar-South Beach-Dongan Hills'}},
#  {'Rego Park': {'nta_code': 'QN0601',
#    'median_rent': '1,646',
#    'median_home_value': '441,970',
#    'percent_atleast_bachdeg': 51.2,
#    'population': '28,213',
#    'nta_name': 'Rego Park'}},
#  {'Wakefield': {'nta_code': 'BX1203',
#    'median_rent': '1,384',
#    'median_home_value': '432,702',
#    'percent_atleast_bachdeg': 26.8,
#    'population': '48,046',
#    'nta_name': 'Wakefield-Woodlawn'}},
#  {'Clifton': {'nta_code': 'SI0102',
#    'median_rent': '1,117',
#    'median_home_value': '384,696',
#    'percent_atleast_bachdeg': 23.8,
#    'population': '15,046',
#    'nta_name': 'Tompkinsville-Stapleton-Clifton-Fox Hills'}},
#  {'Bay Ridge': {'nta_code': 'BK1001',
#    'median_rent': '1,566',
#    'median_home_value': '803,818',
#    'percent_atleast_bachdeg': 49.3,
#    'population': '80,127',
#    'nta_name': 'Bay Ridge'}},
#  {'Graniteville': {'nta_code': 'SI0107',
#    'median_rent': '1,199',
#    'median_home_value': '348,918',
#    'percent_atleast_bachdeg': 25.2,
#    'population': '32,780',
#    'nta_name': "Mariner's Harbor-Arlington-Graniteville"}},
#  {'Spuyten Duyvil': {'nta_code': 'BX0803',
#    'median_rent': '1,723',
#    'median_home_value': '349,531',
#    'percent_atleast_bachdeg': 60.3,
#    'population': '45,308',
#    'nta_name': 'Riverdale-Spuyten Duyvil'}},
#  {'Stapleton': {'nta_code': 'SI0102',
#    'median_rent': '1,117',
#    'median_home_value': '384,696',
#    'percent_atleast_bachdeg': 23.8,
#    'population': '15,046',
#    'nta_name': 'Tompkinsville-Stapleton-Clifton-Fox Hills'}},
#  {'Briarwood': {'nta_code': 'QN0805',
#    'median_rent': '1,617',
#    'median_home_value': '473,528',
#    'percent_atleast_bachdeg': 37.3,
#    'population': '40,618',
#    'nta_name': 'Jamaica Hills-Briarwood'}},
#  {'Ozone Park': {'nta_code': 'QN0904',
#    'median_rent': '1,551',
#    'median_home_value': '556,683',
#    'percent_atleast_bachdeg': 21.6,
#    'population': '25,477',
#    'nta_name': 'Ozone Park (North)'}},
#  {'Columbia St': {'nta_code': 'BK0601',
#    'median_rent': '1,810',
#    'median_home_value': '1,424,561',
#    'percent_atleast_bachdeg': 62.7,
#    'population': '60,893',
#    'nta_name': 'Carroll Gardens-Cobble Hill-Gowanus-Red Hook'}},
#  {'Vinegar Hill': {'nta_code': 'BK0202',
#    'median_rent': '2,558',
#    'median_home_value': '1,115,073',
#    'percent_atleast_bachdeg': 70.7,
#    'population': '35,288',
#    'nta_name': 'Downtown Brooklyn-DUMBO-Boerum Hill'}},
#  {'Mott Haven': {'nta_code': 'BX0101',
#    'median_rent': '803',
#    'median_home_value': '435,810',
#    'percent_atleast_bachdeg': 10.5,
#    'population': '52,835',
#    'nta_name': 'Mott Haven-Port Morris'}},
#  {'Longwood': {'nta_code': 'BX0202',
#    'median_rent': '1,012',
#    'median_home_value': '412,590',
#    'percent_atleast_bachdeg': 13.2,
#    'population': '38,758',
#    'nta_name': 'Longwood'}},
#  {'Canarsie': {'nta_code': 'BK1803',
#    'median_rent': '1,420',
#    'median_home_value': '561,134',
#    'percent_atleast_bachdeg': 28.2,
#    'population': '88,884',
#    'nta_name': 'Canarsie'}},
#  {'Battery Park City': {'nta_code': 'MN0101',
#    'median_rent': '3,279',
#    'median_home_value': '1,034,750',
#    'percent_atleast_bachdeg': 84.8,
#    'population': '46,466',
#    'nta_name': 'Financial District-Battery Park City'}},
#  {'Civic Center': {'nta_code': 'MN0101',
#    'median_rent': '3,279',
#    'median_home_value': '1,034,750',
#    'percent_atleast_bachdeg': 84.8,
#    'population': '46,466',
#    'nta_name': 'Financial District-Battery Park City'}},
#  {'East Elmhurst': {'nta_code': 'QN0301',
#    'median_rent': '1,530',
#    'median_home_value': '419,594',
#    'percent_atleast_bachdeg': 27.3,
#    'population': '91,836',
#    'nta_name': 'Jackson Heights'}},
#  {'New Springville': {'nta_code': 'SI0204',
#    'median_rent': '1,551',
#    'median_home_value': '498,178',
#    'percent_atleast_bachdeg': 34.0,
#    'population': '43,057',
#    'nta_name': 'New Springville-Willowbrook-Bulls Head-Travis'}},
#  {'Morris Heights': {'nta_code': 'BX0501',
#    'median_rent': '1,134',
#    'median_home_value': '383,045',
#    'percent_atleast_bachdeg': 13.2,
#    'population': '55,215',
#    'nta_name': 'University Heights (South)-Morris Heights'}},
#  {'Arverne': {'nta_code': 'QN1402',
#    'median_rent': '1,002',
#    'median_home_value': '395,556',
#    'percent_atleast_bachdeg': 22.7,
#    'population': '41,562',
#    'nta_name': 'Rockaway Beach-Arverne-Edgemere'}},
#  {'Cambria Heights': {'nta_code': 'QN1304',
#    'median_rent': '1,621',
#    'median_home_value': '448,637',
#    'percent_atleast_bachdeg': 34.7,
#    'population': '21,032',
#    'nta_name': 'Cambria Heights'}},
#  {'Tottenville': {'nta_code': 'SI0305',
#    'median_rent': '1,240',
#    'median_home_value': '661,867',
#    'percent_atleast_bachdeg': 38.1,
#    'population': '17,646',
#    'nta_name': 'Tottenville-Charleston'}},
#  {'Mariners Harbor': {'nta_code': 'SI0107',
#    'median_rent': '1,199',
#    'median_home_value': '348,918',
#    'percent_atleast_bachdeg': 25.2,
#    'population': '32,780',
#    'nta_name': "Mariner's Harbor-Arlington-Graniteville"}},
#  {'Concord': {'nta_code': 'SI0201',
#    'median_rent': '1,151',
#    'median_home_value': '490,276',
#    'percent_atleast_bachdeg': 32.6,
#    'population': '35,918',
#    'nta_name': 'Grasmere-Arrochar-South Beach-Dongan Hills'}},
#  {'Borough Park': {'nta_code': 'BK1202',
#    'median_rent': '1,453',
#    'median_home_value': '957,910',
#    'percent_atleast_bachdeg': 19.3,
#    'population': '78,757',
#    'nta_name': 'Borough Park'}},
#  {'Bayside': {'nta_code': 'QN1102',
#    'median_rent': '1,916',
#    'median_home_value': '817,981',
#    'percent_atleast_bachdeg': 45.0,
#    'population': '33,904',
#    'nta_name': 'Bayside'}},
#  {'Downtown Brooklyn': {'nta_code': 'BK0202',
#    'median_rent': '2,558',
#    'median_home_value': '1,115,073',
#    'percent_atleast_bachdeg': 70.7,
#    'population': '35,288',
#    'nta_name': 'Downtown Brooklyn-DUMBO-Boerum Hill'}},
#  {'Port Morris': {'nta_code': 'BX0101',
#    'median_rent': '803',
#    'median_home_value': '435,810',
#    'percent_atleast_bachdeg': 10.5,
#    'population': '52,835',
#    'nta_name': 'Mott Haven-Port Morris'}},
#  {'Fieldston': {'nta_code': 'BX0803',
#    'median_rent': '1,723',
#    'median_home_value': '349,531',
#    'percent_atleast_bachdeg': 60.3,
#    'population': '45,308',
#    'nta_name': 'Riverdale-Spuyten Duyvil'}},
#  {'Kew Gardens': {'nta_code': 'QN0901',
#    'median_rent': '1,572',
#    'median_home_value': '333,873',
#    'percent_atleast_bachdeg': 47.8,
#    'population': '22,376',
#    'nta_name': 'Kew Gardens'}},
#  {'Midwood': {'nta_code': 'BK1402',
#    'median_rent': '1,455',
#    'median_home_value': '839,079',
#    'percent_atleast_bachdeg': 43.6,
#    'population': '39,988',
#    'nta_name': 'Flatbush (West)-Ditmas Park-Parkville'}},
#  {'College Point': {'nta_code': 'QN0701',
#    'median_rent': '1,696',
#    'median_home_value': '673,531',
#    'percent_atleast_bachdeg': 20.3,
#    'population': '28,404',
#    'nta_name': 'College Point'}},
#  {'Mount Eden': {'nta_code': 'BX0403',
#    'median_rent': '1,207',
#    'median_home_value': '379,604',
#    'percent_atleast_bachdeg': 15.7,
#    'population': '50,367',
#    'nta_name': 'Mount Eden-Claremont (West)'}},
#  {'City Island': {'nta_code': 'BX1003',
#    'median_rent': '1,441',
#    'median_home_value': '529,045',
#    'percent_atleast_bachdeg': 32.0,
#    'population': '27,262',
#    'nta_name': 'Pelham Bay-Country Club-City Island'}},
#  {'Glendale': {'nta_code': 'QN0502',
#    'median_rent': '1,576',
#    'median_home_value': '636,024',
#    'percent_atleast_bachdeg': 29.9,
#    'population': '72,983',
#    'nta_name': 'Ridgewood'}},
#  {'Port Richmond': {'nta_code': 'SI0106',
#    'median_rent': '1,349',
#    'median_home_value': '374,070',
#    'percent_atleast_bachdeg': 23.5,
#    'population': '18,557',
#    'nta_name': 'Port Richmond'}},
#  {'Red Hook': {'nta_code': 'BK0601',
#    'median_rent': '1,810',
#    'median_home_value': '1,424,561',
#    'percent_atleast_bachdeg': 62.7,
#    'population': '60,893',
#    'nta_name': 'Carroll Gardens-Cobble Hill-Gowanus-Red Hook'}},
#  {'Richmond Hill': {'nta_code': 'QN0902',
#    'median_rent': '1,514',
#    'median_home_value': '593,713',
#    'percent_atleast_bachdeg': 24.9,
#    'population': '35,709',
#    'nta_name': 'Richmond Hill'}},
#  {'Bellerose': {'nta_code': 'QN1302',
#    'median_rent': '1,726',
#    'median_home_value': '559,476',
#    'percent_atleast_bachdeg': 35.9,
#    'population': '27,643',
#    'nta_name': 'Bellerose'}},
#  {'Maspeth': {'nta_code': 'QN0203',
#    'median_rent': '1,543',
#    'median_home_value': '561,461',
#    'percent_atleast_bachdeg': 30.1,
#    'population': '46,191',
#    'nta_name': 'Woodside'}},
#  {'Williamsbridge': {'nta_code': 'BX1201',
#    'median_rent': '1,371',
#    'median_home_value': '421,810',
#    'percent_atleast_bachdeg': 19.3,
#    'population': '61,635',
#    'nta_name': 'Williamsbridge-Olinville'}},
#  {'Soundview': {'nta_code': 'BX0901',
#    'median_rent': '1,165',
#    'median_home_value': '449,014',
#    'percent_atleast_bachdeg': 14.2,
#    'population': '69,194',
#    'nta_name': 'Soundview-Bruckner-Bronx River'}},
#  {'Woodhaven': {'nta_code': 'QN0905',
#    'median_rent': '1,665',
#    'median_home_value': '504,160',
#    'percent_atleast_bachdeg': 25.0,
#    'population': '40,462',
#    'nta_name': 'Woodhaven'}},
#  {'Woodrow': {'nta_code': 'SI0304',
#    'median_rent': '1,339',
#    'median_home_value': '649,988',
#    'percent_atleast_bachdeg': 37.5,
#    'population': '41,418',
#    'nta_name': "Annadale-Huguenot-Prince's Bay-Woodrow"}},
#  {'Co-op City': {'nta_code': 'BX1004',
#    'median_rent': '1,002',
#    'median_home_value': '26,363',
#    'percent_atleast_bachdeg': 26.0,
#    'population': '36,813',
#    'nta_name': 'Co-op City'}},
#  {'Stuyvesant Town': {'nta_code': 'MN0601',
#    'median_rent': '2,524',
#    'median_home_value': nan,
#    'percent_atleast_bachdeg': 81.5,
#    'population': '22,335',
#    'nta_name': 'Stuyvesant Town-Peter Cooper Village'}},
#  {'Parkchester': {'nta_code': 'BX0901',
#    'median_rent': '1,165',
#    'median_home_value': '449,014',
#    'percent_atleast_bachdeg': 14.2,
#    'population': '69,194',
#    'nta_name': 'Soundview-Bruckner-Bronx River'}},
#  {'North Riverdale': {'nta_code': 'BX0803',
#    'median_rent': '1,723',
#    'median_home_value': '349,531',
#    'percent_atleast_bachdeg': 60.3,
#    'population': '45,308',
#    'nta_name': 'Riverdale-Spuyten Duyvil'}},
#  {'Dyker Heights': {'nta_code': 'BK1002',
#    'median_rent': '1,422',
#    'median_home_value': '897,835',
#    'percent_atleast_bachdeg': 30.0,
#    'population': '42,554',
#    'nta_name': 'Dyker Heights'}},
#  {'Bronxdale': {'nta_code': 'BX1101',
#    'median_rent': '1,403',
#    'median_home_value': '427,911',
#    'percent_atleast_bachdeg': 26.2,
#    'population': '29,261',
#    'nta_name': 'Pelham Parkway-Van Nest'}},
#  {'Sea Gate': {'nta_code': 'BK1302',
#    'median_rent': '880',
#    'median_home_value': '386,594',
#    'percent_atleast_bachdeg': 38.0,
#    'population': '48,372',
#    'nta_name': 'Coney Island-Sea Gate'}},
#  {'Riverdale': {'nta_code': 'BX0803',
#    'median_rent': '1,723',
#    'median_home_value': '349,531',
#    'percent_atleast_bachdeg': 60.3,
#    'population': '45,308',
#    'nta_name': 'Riverdale-Spuyten Duyvil'}},
#  {'Kew Gardens Hills': {'nta_code': 'QN0801',
#    'median_rent': '1,558',
#    'median_home_value': '350,880',
#    'percent_atleast_bachdeg': 44.9,
#    'population': '34,292',
#    'nta_name': 'Kew Gardens Hills'}},
#  {'Bay Terrace': {'nta_code': 'QN0703',
#    'median_rent': '2,070',
#    'median_home_value': '461,578',
#    'percent_atleast_bachdeg': 49.8,
#    'population': '21,990',
#    'nta_name': 'Bay Terrace-Clearview'}},
#  {'Norwood': {'nta_code': 'BX0703',
#    'median_rent': '1,328',
#    'median_home_value': '332,786',
#    'percent_atleast_bachdeg': 21.4,
#    'population': '40,032',
#    'nta_name': 'Norwood'}},
#  {'Claremont Village': {'nta_code': 'BX0403',
#    'median_rent': '1,207',
#    'median_home_value': '379,604',
#    'percent_atleast_bachdeg': 15.7,
#    'population': '50,367',
#    'nta_name': 'Mount Eden-Claremont (West)'}},
#  {'Whitestone': {'nta_code': 'QN0702',
#    'median_rent': '1,763',
#    'median_home_value': '774,726',
#    'percent_atleast_bachdeg': 38.8,
#    'population': '28,095',
#    'nta_name': 'Whitestone-Beechhurst'}},
#  {'Fordham': {'nta_code': 'BX0702',
#    'median_rent': '1,303',
#    'median_home_value': '311,235',
#    'percent_atleast_bachdeg': 16.2,
#    'population': '56,239',
#    'nta_name': 'Bedford Park'}},
#  {'Bayswater': {'nta_code': 'QN1401',
#    'median_rent': '1,297',
#    'median_home_value': '529,433',
#    'percent_atleast_bachdeg': 27.0,
#    'population': '62,096',
#    'nta_name': 'Far Rockaway-Bayswater'}},
#  {'Navy Yard': {'nta_code': 'BK0261',
#    'median_rent': '2,971',
#    'median_home_value': '79,999',
#    'percent_atleast_bachdeg': 68.9,
#    'population': '6',
#    'nta_name': 'Brooklyn Navy Yard'}},
#  {'Brownsville': {'nta_code': 'BK1602',
#    'median_rent': '687',
#    'median_home_value': '410,204',
#    'percent_atleast_bachdeg': 11.1,
#    'population': '47,971',
#    'nta_name': 'Brownsville'}},
#  {'Eltingville': {'nta_code': 'SI0302',
#    'median_rent': '1,603',
#    'median_home_value': '523,531',
#    'percent_atleast_bachdeg': 37.6,
#    'population': '54,152',
#    'nta_name': 'Great Kills-Eltingville'}},
#  {'Fresh Meadows': {'nta_code': 'QN1101',
#    'median_rent': '1,772',
#    'median_home_value': '752,432',
#    'percent_atleast_bachdeg': 35.7,
#    'population': '33,671',
#    'nta_name': 'Auburndale'}},
#  {'Mount Hope': {'nta_code': 'BX0502',
#    'median_rent': '1,248',
#    'median_home_value': '421,428',
#    'percent_atleast_bachdeg': 12.6,
#    'population': '47,167',
#    'nta_name': 'Mount Hope'}},
#  {'Lighthouse Hill': {'nta_code': 'SI0203',
#    'median_rent': '1,226',
#    'median_home_value': '647,364',
#    'percent_atleast_bachdeg': 41.5,
#    'population': '31,111',
#    'nta_name': 'Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights'}},
#  {'Springfield Gardens': {'nta_code': 'QN1305',
#    'median_rent': '1,610',
#    'median_home_value': '454,937',
#    'percent_atleast_bachdeg': 30.4,
#    'population': '25,941',
#    'nta_name': 'Laurelton'}},
#  {'Howard Beach': {'nta_code': 'QN1003',
#    'median_rent': '1,635',
#    'median_home_value': '513,419',
#    'percent_atleast_bachdeg': 27.3,
#    'population': '28,308',
#    'nta_name': 'Howard Beach-Lindenwood'}},
#  {'Belle Harbor': {'nta_code': 'QN1403',
#    'median_rent': '1,418',
#    'median_home_value': '615,257',
#    'percent_atleast_bachdeg': 45.0,
#    'population': '24,768',
#    'nta_name': 'Breezy Point-Belle Harbor-Rockaway Park-Broad Channel'}},
#  {'Jamaica Estates': {'nta_code': 'QN0802',
#    'median_rent': '1,215',
#    'median_home_value': '661,998',
#    'percent_atleast_bachdeg': 33.4,
#    'population': '35,756',
#    'nta_name': 'Pomonok-Electchester-Hillcrest'}},
#  {'Van Nest': {'nta_code': 'BX1101',
#    'median_rent': '1,403',
#    'median_home_value': '427,911',
#    'percent_atleast_bachdeg': 26.2,
#    'population': '29,261',
#    'nta_name': 'Pelham Parkway-Van Nest'}},
#  {'Morris Park': {'nta_code': 'BX1102',
#    'median_rent': '1,470',
#    'median_home_value': '503,429',
#    'percent_atleast_bachdeg': 32.1,
#    'population': '22,296',
#    'nta_name': 'Morris Park'}},
#  {'West Brighton': {'nta_code': 'SI0104',
#    'median_rent': '1,374',
#    'median_home_value': '521,018',
#    'percent_atleast_bachdeg': 39.8,
#    'population': '34,958',
#    'nta_name': 'West New Brighton-Silver Lake-Grymes Hill'}},
#  {'Far Rockaway': {'nta_code': 'QN1401',
#    'median_rent': '1,297',
#    'median_home_value': '529,433',
#    'percent_atleast_bachdeg': 27.0,
#    'population': '62,096',
#    'nta_name': 'Far Rockaway-Bayswater'}},
#  {'South Ozone Park': {'nta_code': 'QN1001',
#    'median_rent': '1,619',
#    'median_home_value': '504,883',
#    'percent_atleast_bachdeg': 20.6,
#    'population': '80,664',
#    'nta_name': 'South Ozone Park'}},
#  {'Tremont': {'nta_code': 'BX0391',
#    'median_rent': '1,048',
#    'median_home_value': '391,332',
#    'percent_atleast_bachdeg': 13.7,
#    'population': '31,270',
#    'nta_name': 'Crotona Park'}},
#  {'Corona': {'nta_code': 'QN0402',
#    'median_rent': '1,583',
#    'median_home_value': '555,918',
#    'percent_atleast_bachdeg': 15.2,
#    'population': '70,079',
#    'nta_name': 'Corona'}},
#  {'Great Kills': {'nta_code': 'SI0302',
#    'median_rent': '1,603',
#    'median_home_value': '523,531',
#    'percent_atleast_bachdeg': 37.6,
#    'population': '54,152',
#    'nta_name': 'Great Kills-Eltingville'}},
#  {'Manhattan Beach': {'nta_code': 'BK1503',
#    'median_rent': '1,296',
#    'median_home_value': '544,973',
#    'percent_atleast_bachdeg': 41.4,
#    'population': '65,167',
#    'nta_name': 'Sheepshead Bay-Manhattan Beach-Gerritsen Beach'}},
#  {'Marble Hill': {'nta_code': 'BX0802',
#    'median_rent': '1,275',
#    'median_home_value': '261,279',
#    'percent_atleast_bachdeg': 27.9,
#    'population': '24,565',
#    'nta_name': 'Kingsbridge-Marble Hill'}},
#  {'Dongan Hills': {'nta_code': 'SI0202',
#    'median_rent': '1,536',
#    'median_home_value': '484,631',
#    'percent_atleast_bachdeg': 29.7,
#    'population': '27,538',
#    'nta_name': 'New Dorp-Midland Beach'}},
#  {'Castleton Corners': {'nta_code': 'SI0105',
#    'median_rent': '1,439',
#    'median_home_value': '524,463',
#    'percent_atleast_bachdeg': 36.9,
#    'population': '30,635',
#    'nta_name': 'Westerleigh-Castleton Corners'}},
#  {'East Morrisania': {'nta_code': 'BX0303',
#    'median_rent': '996',
#    'median_home_value': '421,752',
#    'percent_atleast_bachdeg': 15.7,
#    'population': '27,953',
#    'nta_name': 'Crotona Park East'}},
#  {'Hunts Point': {'nta_code': 'BX0201',
#    'median_rent': '1,094',
#    'median_home_value': '389,436',
#    'percent_atleast_bachdeg': 13.9,
#    'population': '15,397',
#    'nta_name': 'Hunts Point'}},
#  {'Neponsit': {'nta_code': 'QN1403',
#    'median_rent': '1,418',
#    'median_home_value': '615,257',
#    'percent_atleast_bachdeg': 45.0,
#    'population': '24,768',
#    'nta_name': 'Breezy Point-Belle Harbor-Rockaway Park-Broad Channel'}},
#  {'Pelham Bay': {'nta_code': 'BX1003',
#    'median_rent': '1,441',
#    'median_home_value': '529,045',
#    'percent_atleast_bachdeg': 32.0,
#    'population': '27,262',
#    'nta_name': 'Pelham Bay-Country Club-City Island'}},
#  {'Randall Manor': {'nta_code': 'SI0104',
#    'median_rent': '1,374',
#    'median_home_value': '521,018',
#    'percent_atleast_bachdeg': 39.8,
#    'population': '34,958',
#    'nta_name': 'West New Brighton-Silver Lake-Grymes Hill'}},
#  {'Throgs Neck': {'nta_code': 'BX1002',
#    'median_rent': '1,383',
#    'median_home_value': '455,753',
#    'percent_atleast_bachdeg': 25.9,
#    'population': '45,634',
#    'nta_name': 'Throgs Neck-Schuylerville'}},
#  {'Todt Hill': {'nta_code': 'SI0203',
#    'median_rent': '1,226',
#    'median_home_value': '647,364',
#    'percent_atleast_bachdeg': 41.5,
#    'population': '31,111',
#    'nta_name': 'Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights'}},
#  {'West Farms': {'nta_code': 'BX0601',
#    'median_rent': '1,041',
#    'median_home_value': '420,387',
#    'percent_atleast_bachdeg': 10.7,
#    'population': '18,539',
#    'nta_name': 'West Farms'}},
#  {'Silver Lake': {'nta_code': 'SI0104',
#    'median_rent': '1,374',
#    'median_home_value': '521,018',
#    'percent_atleast_bachdeg': 39.8,
#    'population': '34,958',
#    'nta_name': 'West New Brighton-Silver Lake-Grymes Hill'}},
#  {'Morrisania': {'nta_code': 'BX0301',
#    'median_rent': '1,014',
#    'median_home_value': '369,918',
#    'percent_atleast_bachdeg': 13.4,
#    'population': '34,170',
#    'nta_name': 'Morrisania'}},
#  {'Laurelton': {'nta_code': 'QN1305',
#    'median_rent': '1,610',
#    'median_home_value': '454,937',
#    'percent_atleast_bachdeg': 30.4,
#    'population': '25,941',
#    'nta_name': 'Laurelton'}},
#  {'Grymes Hill': {'nta_code': 'SI0104',
#    'median_rent': '1,374',
#    'median_home_value': '521,018',
#    'percent_atleast_bachdeg': 39.8,
#    'population': '34,958',
#    'nta_name': 'West New Brighton-Silver Lake-Grymes Hill'}},
#  {'Holliswood': {'nta_code': 'QN0804',
#    'median_rent': '1,586',
#    'median_home_value': '676,587',
#    'percent_atleast_bachdeg': 47.9,
#    'population': '23,806',
#    'nta_name': 'Jamaica Estates-Holliswood'}},
#  {'Pelham Gardens': {'nta_code': 'BX1103',
#    'median_rent': '1,446',
#    'median_home_value': '484,665',
#    'percent_atleast_bachdeg': 29.2,
#    'population': '29,209',
#    'nta_name': 'Pelham Gardens'}},
#  {'Belmont': {'nta_code': 'BX0603',
#    'median_rent': '1,180',
#    'median_home_value': '398,895',
#    'percent_atleast_bachdeg': 13.6,
#    'population': '36,212',
#    'nta_name': 'Belmont'}},
#  {'Rosedale': {'nta_code': 'QN1307',
#    'median_rent': '1,787',
#    'median_home_value': '468,095',
#    'percent_atleast_bachdeg': 24.6,
#    'population': '26,637',
#    'nta_name': 'Rosedale'}},
#  {'Edgemere': {'nta_code': 'QN1402',
#    'median_rent': '1,002',
#    'median_home_value': '395,556',
#    'percent_atleast_bachdeg': 22.7,
#    'population': '41,562',
#    'nta_name': 'Rockaway Beach-Arverne-Edgemere'}},
#  {'New Brighton': {'nta_code': 'SI0101',
#    'median_rent': '1,166',
#    'median_home_value': '397,727',
#    'percent_atleast_bachdeg': 34.6,
#    'population': '17,221',
#    'nta_name': 'St. George-New Brighton'}},
#  {'Midland Beach': {'nta_code': 'SI0202',
#    'median_rent': '1,536',
#    'median_home_value': '484,631',
#    'percent_atleast_bachdeg': 29.7,
#    'population': '27,538',
#    'nta_name': 'New Dorp-Midland Beach'}},
#  {'Baychester': {'nta_code': 'BX1202',
#    'median_rent': '1,314',
#    'median_home_value': '447,038',
#    'percent_atleast_bachdeg': 24.7,
#    'population': '55,008',
#    'nta_name': 'Eastchester-Edenwald-Baychester'}},
#  {'Melrose': {'nta_code': 'BX0102',
#    'median_rent': '1,040',
#    'median_home_value': '316,274',
#    'percent_atleast_bachdeg': 13.4,
#    'population': '42,877',
#    'nta_name': 'Melrose'}},
#  {'Bergen Beach': {'nta_code': 'BK1802',
#    'median_rent': '1,651',
#    'median_home_value': '650,142',
#    'percent_atleast_bachdeg': 40.4,
#    'population': '46,179',
#    'nta_name': 'Marine Park-Mill Basin-Bergen Beach'}},
#  {'Richmondtown': {'nta_code': 'SI0301',
#    'median_rent': '1,370',
#    'median_home_value': '550,168',
#    'percent_atleast_bachdeg': 28.2,
#    'population': '20,485',
#    'nta_name': 'Oakwood-Richmondtown'}},
#  {'Howland Hook': {'nta_code': 'SI0107',
#    'median_rent': '1,199',
#    'median_home_value': '348,918',
#    'percent_atleast_bachdeg': 25.2,
#    'population': '32,780',
#    'nta_name': "Mariner's Harbor-Arlington-Graniteville"}},
#  {'Schuylerville': {'nta_code': 'BX1002',
#    'median_rent': '1,383',
#    'median_home_value': '455,753',
#    'percent_atleast_bachdeg': 25.9,
#    'population': '45,634',
#    'nta_name': 'Throgs Neck-Schuylerville'}},
#  {'Coney Island': {'nta_code': 'BK1302',
#    'median_rent': '880',
#    'median_home_value': '386,594',
#    'percent_atleast_bachdeg': 38.0,
#    'population': '48,372',
#    'nta_name': 'Coney Island-Sea Gate'}},
#  {'New Dorp Beach': {'nta_code': 'SI0202',
#    'median_rent': '1,536',
#    'median_home_value': '484,631',
#    'percent_atleast_bachdeg': 29.7,
#    'population': '27,538',
#    'nta_name': 'New Dorp-Midland Beach'}},
#  {"Prince's Bay": {'nta_code': 'SI0304',
#    'median_rent': '1,339',
#    'median_home_value': '649,988',
#    'percent_atleast_bachdeg': 37.5,
#    'population': '41,418',
#    'nta_name': "Annadale-Huguenot-Prince's Bay-Woodrow"}},
#  {'South Beach': {'nta_code': 'SI0201',
#    'median_rent': '1,151',
#    'median_home_value': '490,276',
#    'percent_atleast_bachdeg': 32.6,
#    'population': '35,918',
#    'nta_name': 'Grasmere-Arrochar-South Beach-Dongan Hills'}},
#  {'Bath Beach': {'nta_code': 'BK1102',
#    'median_rent': '1,460',
#    'median_home_value': '814,982',
#    'percent_atleast_bachdeg': 34.4,
#    'population': '33,580',
#    'nta_name': 'Bath Beach'}},
#  {'Jamaica Hills': {'nta_code': 'QN0805',
#    'median_rent': '1,617',
#    'median_home_value': '473,528',
#    'percent_atleast_bachdeg': 37.3,
#    'population': '40,618',
#    'nta_name': 'Jamaica Hills-Briarwood'}},
#  {'Oakwood': {'nta_code': 'SI0301',
#    'median_rent': '1,370',
#    'median_home_value': '550,168',
#    'percent_atleast_bachdeg': 28.2,
#    'population': '20,485',
#    'nta_name': 'Oakwood-Richmondtown'}},
#  {'Castle Hill': {'nta_code': 'BX0903',
#    'median_rent': '1,288',
#    'median_home_value': '459,975',
#    'percent_atleast_bachdeg': 17.5,
#    'population': '39,677',
#    'nta_name': 'Castle Hill-Unionport'}},
#  {'Hollis': {'nta_code': 'QN1206',
#    'median_rent': '1,391',
#    'median_home_value': '478,813',
#    'percent_atleast_bachdeg': 24.0,
#    'population': '22,496',
#    'nta_name': 'Hollis'}},
#  {'Douglaston': {'nta_code': 'QN1103',
#    'median_rent': '2,052',
#    'median_home_value': '628,732',
#    'percent_atleast_bachdeg': 49.0,
#    'population': '25,400',
#    'nta_name': 'Douglaston-Little Neck'}},
#  {'Huguenot': {'nta_code': 'SI0304',
#    'median_rent': '1,339',
#    'median_home_value': '649,988',
#    'percent_atleast_bachdeg': 37.5,
#    'population': '41,418',
#    'nta_name': "Annadale-Huguenot-Prince's Bay-Woodrow"}},
#  {'Olinville': {'nta_code': 'BX1201',
#    'median_rent': '1,371',
#    'median_home_value': '421,810',
#    'percent_atleast_bachdeg': 19.3,
#    'population': '61,635',
#    'nta_name': 'Williamsbridge-Olinville'}},
#  {'Edenwald': {'nta_code': 'BX1202',
#    'median_rent': '1,314',
#    'median_home_value': '447,038',
#    'percent_atleast_bachdeg': 24.7,
#    'population': '55,008',
#    'nta_name': 'Eastchester-Edenwald-Baychester'}},
#  {'Grant City': {'nta_code': 'SI0202',
#    'median_rent': '1,536',
#    'median_home_value': '484,631',
#    'percent_atleast_bachdeg': 29.7,
#    'population': '27,538',
#    'nta_name': 'New Dorp-Midland Beach'}},
#  {'Westerleigh': {'nta_code': 'SI0105',
#    'median_rent': '1,439',
#    'median_home_value': '524,463',
#    'percent_atleast_bachdeg': 36.9,
#    'population': '30,635',
#    'nta_name': 'Westerleigh-Castleton Corners'}},
#  {'Bay Terrace, Staten Island': {'nta_code': 'SI0302',
#    'median_rent': '1,603',
#    'median_home_value': '523,531',
#    'percent_atleast_bachdeg': 37.6,
#    'population': '54,152',
#    'nta_name': 'Great Kills-Eltingville'}},
#  {'Westchester Square': {'nta_code': 'BX1001',
#    'median_rent': '1,337',
#    'median_home_value': '489,673',
#    'percent_atleast_bachdeg': 23.1,
#    'population': '15,136',
#    'nta_name': 'Westchester Square'}},
#  {'Little Neck': {'nta_code': 'QN1103',
#    'median_rent': '2,052',
#    'median_home_value': '628,732',
#    'percent_atleast_bachdeg': 49.0,
#    'population': '25,400',
#    'nta_name': 'Douglaston-Little Neck'}},
#  {'Fort Wadsworth': {'nta_code': 'SI9561',
#    'median_rent': '1,962',
#    'median_home_value': '74,999',
#    'percent_atleast_bachdeg': 42.8,
#    'population': '588',
#    'nta_name': 'Fort Wadsworth'}},
#  {'Rosebank': {'nta_code': 'SI0103',
#    'median_rent': '1,116',
#    'median_home_value': '431,029',
#    'percent_atleast_bachdeg': 29.3,
#    'population': '22,783',
#    'nta_name': 'Rosebank-Shore Acres-Park Hill'}},
#  {'Unionport': {'nta_code': 'BX0903',
#    'median_rent': '1,288',
#    'median_home_value': '459,975',
#    'percent_atleast_bachdeg': 17.5,
#    'population': '39,677',
#    'nta_name': 'Castle Hill-Unionport'}},
#  {'Mill Basin': {'nta_code': 'BK1802',
#    'median_rent': '1,651',
#    'median_home_value': '650,142',
#    'percent_atleast_bachdeg': 40.4,
#    'population': '46,179',
#    'nta_name': 'Marine Park-Mill Basin-Bergen Beach'}},
#  {'Arden Heights': {'nta_code': 'SI0303',
#    'median_rent': '1,242',
#    'median_home_value': '444,250',
#    'percent_atleast_bachdeg': 32.8,
#    'population': '30,900',
#    'nta_name': 'Arden Heights-Rossville'}},
#  {"Bull's Head": {'nta_code': 'SI0204',
#    'median_rent': '1,551',
#    'median_home_value': '498,178',
#    'percent_atleast_bachdeg': 34.0,
#    'population': '43,057',
#    'nta_name': 'New Springville-Willowbrook-Bulls Head-Travis'}},
#  {'New Dorp': {'nta_code': 'SI0202',
#    'median_rent': '1,536',
#    'median_home_value': '484,631',
#    'percent_atleast_bachdeg': 29.7,
#    'population': '27,538',
#    'nta_name': 'New Dorp-Midland Beach'}},
#  {'Rossville': {'nta_code': 'SI0303',
#    'median_rent': '1,242',
#    'median_home_value': '444,250',
#    'percent_atleast_bachdeg': 32.8,
#    'population': '30,900',
#    'nta_name': 'Arden Heights-Rossville'}},
#  {'Breezy Point': {'nta_code': 'QN8492',
#    'median_rent': '1,418',
#    'median_home_value': '615,257',
#    'percent_atleast_bachdeg': 45.0,
#    'population': '24,768',
#    'nta_name': 'Jacob Riis Park-Fort Tilden-Breezy Point Tip'}},
#  {'Willowbrook': {'nta_code': 'SI0203',
#    'median_rent': '1,226',
#    'median_home_value': '647,364',
#    'percent_atleast_bachdeg': 41.5,
#    'population': '31,111',
#    'nta_name': 'Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights'}}]

# %%
# with open("side_input.json", "w") as f:
#     json.dump(dicts, f)
